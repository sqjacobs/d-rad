# %%
import pandas as pd
import numpy as np; np.random.seed(1)
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import matplotlib
from scipy import signal
from statsmodels.stats.weightstats import ttest_ind
micron_conv = 0.01537697 
import math
import matplotlib.pyplot as plt
import statistics
micron_conv = 0.00384424219

# %%
#import residues at 10kgy
residues_10kgy = pd.read_excel(r'C:\Users\sqjac\OneDrive\Desktop\slices\data.xlsx',sheet_name='10kresidues').dropna()

#create lists and find avg,stdev,err
residues_10kgy_d1 = residues_10kgy['d1a1'].tolist()
residues_10kgy_d1.extend(residues_10kgy['d1b2'].tolist())
residues_10kgy_d1.extend(residues_10kgy['d1b3'].tolist())
residues_10kgy_d1.extend(residues_10kgy['d1c1'].tolist())
residues_10kgy_d1.extend(residues_10kgy['d1c2'].tolist())
residues_10kgy_d1 = [i * micron_conv for i in residues_10kgy_d1]
avg_residues_10kgy_d1 = statistics.mean(residues_10kgy_d1)
stdev_residues_10kgy_d1 = statistics.stdev(residues_10kgy_d1)
err_residues_10kgy_d1 = stdev_residues_10kgy_d1/math.sqrt(len(residues_10kgy_d1))
print('d1')
print(avg_residues_10kgy_d1)
print(stdev_residues_10kgy_d1)
print(err_residues_10kgy_d1)

residues_10kgy_d2 = residues_10kgy['d2a1'].tolist()
residues_10kgy_d2.extend(residues_10kgy['d2a2'].tolist())
residues_10kgy_d2.extend(residues_10kgy['d2b1'].tolist())
residues_10kgy_d2.extend(residues_10kgy['d2b2'].tolist())
residues_10kgy_d2.extend(residues_10kgy['d2c1'].tolist())
residues_10kgy_d2.extend(residues_10kgy['d2c2'].tolist())
residues_10kgy_d2 = [i * micron_conv for i in residues_10kgy_d2]
avg_residues_10kgy_d2 = statistics.mean(residues_10kgy_d2)
stdev_residues_10kgy_d2 = statistics.stdev(residues_10kgy_d2)
err_residues_10kgy_d2 = stdev_residues_10kgy_d2/math.sqrt(len(residues_10kgy_d2))
print('d2')
print(avg_residues_10kgy_d2)
print(stdev_residues_10kgy_d2)
print(err_residues_10kgy_d2)

residues_10kgy_g = residues_10kgy['gc2'].tolist()
residues_10kgy_g.extend(residues_10kgy['gc3'].tolist())
residues_10kgy_g = [i * micron_conv for i in residues_10kgy_g]
avg_residues_10kgy_g = statistics.mean(residues_10kgy_g)
stdev_residues_10kgy_g = statistics.stdev(residues_10kgy_g)
err_residues_10kgy_g = stdev_residues_10kgy_g/math.sqrt(len(residues_10kgy_g))
print('g')
print(avg_residues_10kgy_g)
print(stdev_residues_10kgy_g)
print(err_residues_10kgy_g)

residues_10kgy_h = residues_10kgy['ha2'].tolist()
residues_10kgy_h.extend(residues_10kgy['ha3'].tolist())
residues_10kgy_h.extend(residues_10kgy['ha4'].tolist())
residues_10kgy_h.extend(residues_10kgy['hb1'].tolist())
residues_10kgy_h.extend(residues_10kgy['hb2'].tolist())
residues_10kgy_h = [i * micron_conv for i in residues_10kgy_h]
avg_residues_10kgy_h = statistics.mean(residues_10kgy_h)
stdev_residues_10kgy_h = statistics.stdev(residues_10kgy_h)
err_residues_10kgy_h = stdev_residues_10kgy_h/math.sqrt(len(residues_10kgy_h))
print('h')
print(avg_residues_10kgy_h)
print(stdev_residues_10kgy_h)
print(err_residues_10kgy_h)

#average columns
#avg_residues_10kgy = residues_10kgy[['d1a1','d1b2','d1b3','d1c1','d1c2','d2a1','d2a2','d2b1','d2b2','d2c1','d2c2',
#                                     'gc2','gc3','ha2','ha3','ha4','hb1','hb2']].mean(skipna=True)
#avg_footprints_10kgy = footprints_10kgy[['d1a1','d1b2','d1b3','d1c1','d1c2','d2a1','d2a2','d2b1','d2b2','d2c1','d2c2',
#                                     'gc2','gc3','ha2','ha3','ha4','hb1','hb2']].mean(skipna=True)
# Out:
# d1
# 3.4375854370011667
# 0.9173706057346668
# 0.11843203594368581
# d2
# 4.525740902682778
# 0.8136338783091475
# 0.09588767212591807
# g
# 2.6666226657966665
# 0.8459312953381892
# 0.1726750025858485
# h
# 1.211705138288
# 0.8078952873161553
# 0.10429883310849752

# %%
#import residues at 0kgy
residues_0kgy = pd.read_excel(r'C:\Users\sqjac\OneDrive\Desktop\slices\data.xlsx',sheet_name='0kresidues').dropna()

#create lists and find avg,stdev,err
residues_0kgy_d1 = residues_0kgy['d1a1'].tolist()
residues_0kgy_d1.extend(residues_0kgy['d1a2'].tolist())
residues_0kgy_d1.extend(residues_0kgy['d1b1'].tolist())
residues_0kgy_d1.extend(residues_0kgy['d1b2'].tolist())
residues_0kgy_d1.extend(residues_0kgy['d1c1'].tolist())
residues_0kgy_d1.extend(residues_0kgy['d1c2'].tolist())
residues_0kgy_d1 = [i * micron_conv for i in residues_0kgy_d1]
avg_residues_0kgy_d1 = statistics.mean(residues_0kgy_d1)
stdev_residues_0kgy_d1 = statistics.stdev(residues_0kgy_d1)
err_residues_0kgy_d1 = stdev_residues_0kgy_d1/math.sqrt(len(residues_0kgy_d1))
print('d1')
print(avg_residues_0kgy_d1)
print(stdev_residues_0kgy_d1)
print(err_residues_0kgy_d1)

residues_0kgy_d2 = residues_0kgy['d2a1'].tolist()
residues_0kgy_d2.extend(residues_0kgy['d2a2'].tolist())
residues_0kgy_d2.extend(residues_0kgy['d2b1'].tolist())
residues_0kgy_d2.extend(residues_0kgy['d2b2'].tolist())
residues_0kgy_d2.extend(residues_0kgy['d2c1'].tolist())
residues_0kgy_d2.extend(residues_0kgy['d2c2'].tolist())
residues_0kgy_d2 = [i * micron_conv for i in residues_0kgy_d2]
avg_residues_0kgy_d2 = statistics.mean(residues_0kgy_d2)
stdev_residues_0kgy_d2 = statistics.stdev(residues_0kgy_d2)
err_residues_0kgy_d2 = stdev_residues_0kgy_d2/math.sqrt(len(residues_0kgy_d2))
print('d2')
print(avg_residues_0kgy_d2)
print(stdev_residues_0kgy_d2)
print(err_residues_0kgy_d2)

residues_0kgy_g = residues_0kgy['ga1'].tolist()
residues_0kgy_g.extend(residues_0kgy['ga2'].tolist())
residues_0kgy_g.extend(residues_0kgy['gb1'].tolist())
residues_0kgy_g.extend(residues_0kgy['gb2'].tolist())
residues_0kgy_g.extend(residues_0kgy['gc1'].tolist())
residues_0kgy_g.extend(residues_0kgy['gc2'].tolist())
residues_0kgy_g = [i * micron_conv for i in residues_0kgy_g]
avg_residues_0kgy_g = statistics.mean(residues_0kgy_g)
stdev_residues_0kgy_g = statistics.stdev(residues_0kgy_g)
err_residues_0kgy_g = stdev_residues_0kgy_g/math.sqrt(len(residues_0kgy_g))
print('g')
print(avg_residues_0kgy_g)
print(stdev_residues_0kgy_g)
print(err_residues_0kgy_g)

residues_0kgy_h = residues_0kgy['ha1'].tolist()
residues_0kgy_h.extend(residues_0kgy['ha2'].tolist())
residues_0kgy_h.extend(residues_0kgy['hb1'].tolist())
residues_0kgy_h.extend(residues_0kgy['hb2'].tolist())
residues_0kgy_h.extend(residues_0kgy['hc1'].tolist())
residues_0kgy_h.extend(residues_0kgy['hc2'].tolist())
residues_0kgy_h = [i * micron_conv for i in residues_0kgy_h]
avg_residues_0kgy_h = statistics.mean(residues_0kgy_h)
stdev_residues_0kgy_h = statistics.stdev(residues_0kgy_h)
err_residues_0kgy_h = stdev_residues_0kgy_h/math.sqrt(len(residues_0kgy_h))
print('h')
print(avg_residues_0kgy_h)
print(stdev_residues_0kgy_h)
print(err_residues_0kgy_h)
# Out:
# d1
# 2.8878550349662744
# 0.8674094845229421
# 0.08588633698550548
# d2
# 3.6470928674912746
# 0.8077517070930359
# 0.07997933681133838
# g
# 2.114069383957549
# 1.0465428022884729
# 0.1036231784305855
# h
# 1.2129714768917648
# 0.798113230879971
# 0.07902498545729784

# %%
#import footprints at 10kgy
footprints_10kgy = pd.read_excel(r'C:\Users\sqjac\OneDrive\Desktop\slices\data.xlsx',sheet_name='10kfootprints').dropna()

#create lists and find avg,stdev,err
footprints_10kgy_d1 = footprints_10kgy['d1a1'].tolist()
footprints_10kgy_d1.extend(footprints_10kgy['d1b2'].tolist())
footprints_10kgy_d1.extend(footprints_10kgy['d1b3'].tolist())
footprints_10kgy_d1.extend(footprints_10kgy['d1c1'].tolist())
footprints_10kgy_d1.extend(footprints_10kgy['d1c2'].tolist())
avg_footprints_10kgy_d1 = statistics.mean(footprints_10kgy_d1)
stdev_footprints_10kgy_d1 = statistics.stdev(footprints_10kgy_d1)
err_footprints_10kgy_d1 = stdev_footprints_10kgy_d1/math.sqrt(len(footprints_10kgy_d1))
print('d1')
print(avg_footprints_10kgy_d1)
print(stdev_footprints_10kgy_d1)
print(err_footprints_10kgy_d1)

footprints_10kgy_d2 = footprints_10kgy['d2a1'].tolist()
footprints_10kgy_d2.extend(footprints_10kgy['d2a2'].tolist())
footprints_10kgy_d2.extend(footprints_10kgy['d2b1'].tolist())
footprints_10kgy_d2.extend(footprints_10kgy['d2b2'].tolist())
footprints_10kgy_d2.extend(footprints_10kgy['d2c1'].tolist())
footprints_10kgy_d2.extend(footprints_10kgy['d2c2'].tolist())
avg_footprints_10kgy_d2 = statistics.mean(footprints_10kgy_d2)
stdev_footprints_10kgy_d2 = statistics.stdev(footprints_10kgy_d2)
err_footprints_10kgy_d2 = stdev_footprints_10kgy_d2/math.sqrt(len(footprints_10kgy_d2))
print('d2')
print(avg_footprints_10kgy_d2)
print(stdev_footprints_10kgy_d2)
print(err_footprints_10kgy_d2)

footprints_10kgy_g = footprints_10kgy['gc2'].tolist()
footprints_10kgy_g.extend(footprints_10kgy['gc3'].tolist())
avg_footprints_10kgy_g = statistics.mean(footprints_10kgy_g)
stdev_footprints_10kgy_g = statistics.stdev(footprints_10kgy_g)
err_footprints_10kgy_g = stdev_footprints_10kgy_g/math.sqrt(len(footprints_10kgy_g))
print('g')
print(avg_footprints_10kgy_g)
print(stdev_footprints_10kgy_g)
print(err_footprints_10kgy_g)

footprints_10kgy_h = footprints_10kgy['ha2'].tolist()
footprints_10kgy_h.extend(footprints_10kgy['ha3'].tolist())
footprints_10kgy_h.extend(footprints_10kgy['ha4'].tolist())
footprints_10kgy_h.extend(footprints_10kgy['hb1'].tolist())
footprints_10kgy_h.extend(footprints_10kgy['hb2'].tolist())
avg_footprints_10kgy_h = statistics.mean(footprints_10kgy_h)
stdev_footprints_10kgy_h = statistics.stdev(footprints_10kgy_h)
err_footprints_10kgy_h = stdev_footprints_10kgy_h/math.sqrt(len(footprints_10kgy_h))
print('h')
print(avg_footprints_10kgy_h)
print(stdev_footprints_10kgy_h)
print(err_footprints_10kgy_h)
# Out:
# d1
# 5.14865
# 1.3596481826224291
# 0.17552982559992827
# d2
# 6.273625
# 1.110220717016647
# 0.13084076626937702
# g
# 4.429333333333333
# 1.0454989100972285
# 0.2134115713645128
# h
# 2.9881166666666665
# 1.1650393328875817
# 0.15040593113167341

# %%
#import footprints at 0kgy
footprints_0kgy = pd.read_excel(r'C:\Users\sqjac\OneDrive\Desktop\slices\data.xlsx',sheet_name='0kfootprints').dropna()

#create lists and find avg,stdev,err
footprints_0kgy_d1 = footprints_0kgy['d1a1'].tolist()
footprints_0kgy_d1.extend(footprints_0kgy['d1a2'].tolist())
footprints_0kgy_d1.extend(footprints_0kgy['d1b1'].tolist())
footprints_0kgy_d1.extend(footprints_0kgy['d1b2'].tolist())
footprints_0kgy_d1.extend(footprints_0kgy['d1c1'].tolist())
footprints_0kgy_d1.extend(footprints_0kgy['d1c2'].tolist())
avg_footprints_0kgy_d1 = statistics.mean(footprints_0kgy_d1)
stdev_footprints_0kgy_d1 = statistics.stdev(footprints_0kgy_d1)
err_footprints_0kgy_d1 = stdev_footprints_0kgy_d1/math.sqrt(len(footprints_0kgy_d1))
print('d1')
print(avg_footprints_0kgy_d1)
print(stdev_footprints_0kgy_d1)
print(err_footprints_0kgy_d1)

footprints_0kgy_d2 = footprints_0kgy['d2a1'].tolist()
footprints_0kgy_d2.extend(footprints_0kgy['d2a2'].tolist())
footprints_0kgy_d2.extend(footprints_0kgy['d2b1'].tolist())
footprints_0kgy_d2.extend(footprints_0kgy['d2b2'].tolist())
footprints_0kgy_d2.extend(footprints_0kgy['d2c1'].tolist())
footprints_0kgy_d2.extend(footprints_0kgy['d2c2'].tolist())
avg_footprints_0kgy_d2 = statistics.mean(footprints_0kgy_d2)
stdev_footprints_0kgy_d2 = statistics.stdev(footprints_0kgy_d2)
err_footprints_0kgy_d2 = stdev_footprints_0kgy_d2/math.sqrt(len(footprints_0kgy_d2))
print('d2')
print(avg_footprints_0kgy_d2)
print(stdev_footprints_0kgy_d2)
print(err_footprints_0kgy_d2)

footprints_0kgy_g = footprints_0kgy['ga1'].tolist()
footprints_0kgy_g.extend(footprints_0kgy['ga2'].tolist())
footprints_0kgy_g.extend(footprints_0kgy['gb1'].tolist())
footprints_0kgy_g.extend(footprints_0kgy['gb2'].tolist())
footprints_0kgy_g.extend(footprints_0kgy['gc1'].tolist())
footprints_0kgy_g.extend(footprints_0kgy['gc2'].tolist())
avg_footprints_0kgy_g = statistics.mean(footprints_0kgy_g)
stdev_footprints_0kgy_g = statistics.stdev(footprints_0kgy_g)
err_footprints_0kgy_g = stdev_footprints_0kgy_g/math.sqrt(len(footprints_0kgy_g))
print('g')
print(avg_footprints_0kgy_g)
print(stdev_footprints_0kgy_g)
print(err_footprints_0kgy_g)

footprints_0kgy_h = footprints_0kgy['ha1'].tolist()
footprints_0kgy_h.extend(footprints_0kgy['ha2'].tolist())
footprints_0kgy_h.extend(footprints_0kgy['hb1'].tolist())
footprints_0kgy_h.extend(footprints_0kgy['hb2'].tolist())
footprints_0kgy_h.extend(footprints_0kgy['hc1'].tolist())
footprints_0kgy_h.extend(footprints_0kgy['hc2'].tolist())
avg_footprints_0kgy_h = statistics.mean(footprints_0kgy_h)
stdev_footprints_0kgy_h = statistics.stdev(footprints_0kgy_h)
err_footprints_0kgy_h = stdev_footprints_0kgy_h/math.sqrt(len(footprints_0kgy_h))
print('h')
print(avg_footprints_0kgy_h)
print(stdev_footprints_0kgy_h)
print(err_footprints_0kgy_h)
# Out:
# d1
# 5.660627450980392
# 1.2794682676611617
# 0.12668623615413213
# d2
# 5.683872549019608
# 1.1863662105672161
# 0.11746775884636769
# g
# 4.391705882352941
# 1.5870456804535413
# 0.1571409381092818
# h
# 3.7801666666666667
# 1.2741288391210162
# 0.12615755394913966

# %%
#import intensities at 10kgy
intensities_10kgy = pd.read_excel(r'C:\Users\sqjac\OneDrive\Desktop\slices\data.xlsx',sheet_name='10kintensities').dropna()

#create lists and find avg,stdev,err
intensities_10kgy_d1 = intensities_10kgy['d1a1'].tolist()
intensities_10kgy_d1.extend(intensities_10kgy['d1b2'].tolist())
intensities_10kgy_d1.extend(intensities_10kgy['d1b3'].tolist())
intensities_10kgy_d1.extend(intensities_10kgy['d1c1'].tolist())
intensities_10kgy_d1.extend(intensities_10kgy['d1c2'].tolist())
avg_intensities_10kgy_d1 = statistics.mean(intensities_10kgy_d1)
stdev_intensities_10kgy_d1 = statistics.stdev(intensities_10kgy_d1)
err_intensities_10kgy_d1 = stdev_intensities_10kgy_d1/math.sqrt(len(intensities_10kgy_d1))
print('d1')
print(avg_intensities_10kgy_d1)
print(stdev_intensities_10kgy_d1)
print(err_intensities_10kgy_d1)

intensities_10kgy_d2 = intensities_10kgy['d2a1'].tolist()
intensities_10kgy_d2.extend(intensities_10kgy['d2a2'].tolist())
intensities_10kgy_d2.extend(intensities_10kgy['d2b1'].tolist())
intensities_10kgy_d2.extend(intensities_10kgy['d2b2'].tolist())
intensities_10kgy_d2.extend(intensities_10kgy['d2c1'].tolist())
intensities_10kgy_d2.extend(intensities_10kgy['d2c2'].tolist())
avg_intensities_10kgy_d2 = statistics.mean(intensities_10kgy_d2)
stdev_intensities_10kgy_d2 = statistics.stdev(intensities_10kgy_d2)
err_intensities_10kgy_d2 = stdev_intensities_10kgy_d2/math.sqrt(len(intensities_10kgy_d2))
print('d2')
print(avg_intensities_10kgy_d2)
print(stdev_intensities_10kgy_d2)
print(err_intensities_10kgy_d2)

intensities_10kgy_g = intensities_10kgy['gc2'].tolist()
intensities_10kgy_g.extend(intensities_10kgy['gc3'].tolist())
avg_intensities_10kgy_g = statistics.mean(intensities_10kgy_g)
stdev_intensities_10kgy_g = statistics.stdev(intensities_10kgy_g)
err_intensities_10kgy_g = stdev_intensities_10kgy_g/math.sqrt(len(intensities_10kgy_g))
print('g')
print(avg_intensities_10kgy_g)
print(stdev_intensities_10kgy_g)
print(err_intensities_10kgy_g)

intensities_10kgy_h = intensities_10kgy['ha2'].tolist()
intensities_10kgy_h.extend(intensities_10kgy['ha3'].tolist())
intensities_10kgy_h.extend(intensities_10kgy['ha4'].tolist())
intensities_10kgy_h.extend(intensities_10kgy['hb1'].tolist())
intensities_10kgy_h.extend(intensities_10kgy['hb2'].tolist())
avg_intensities_10kgy_h = statistics.mean(intensities_10kgy_h)
stdev_intensities_10kgy_h = statistics.stdev(intensities_10kgy_h)
err_intensities_10kgy_h = stdev_intensities_10kgy_h/math.sqrt(len(intensities_10kgy_h))
print('h')
print(avg_intensities_10kgy_h)
print(stdev_intensities_10kgy_h)
print(err_intensities_10kgy_h)
# Out:
# d1
# 211.72676666666666
# 42.06582608220753
# 5.430674795361578
# d2
# 64.49151388888889
# 7.548105123642018
# 0.8895527196726992
# g
# 76.52225
# 10.875350646021168
# 2.219921654716605
# h
# 487.97113333333334
# 201.1401926715494
# 25.967087215662065

# %%
#import intensities at 0kgy
intensities_0kgy = pd.read_excel(r'C:\Users\sqjac\OneDrive\Desktop\slices\data.xlsx',sheet_name='0kintensities').dropna()

#create lists and find avg,stdev,err
intensities_0kgy_d1 = intensities_0kgy['d1a1'].tolist()
intensities_0kgy_d1.extend(intensities_0kgy['d1a2'].tolist())
intensities_0kgy_d1.extend(intensities_0kgy['d1b1'].tolist())
intensities_0kgy_d1.extend(intensities_0kgy['d1b2'].tolist())
intensities_0kgy_d1.extend(intensities_0kgy['d1c1'].tolist())
intensities_0kgy_d1.extend(intensities_0kgy['d1c2'].tolist())
avg_intensities_0kgy_d1 = statistics.mean(intensities_0kgy_d1)
stdev_intensities_0kgy_d1 = statistics.stdev(intensities_0kgy_d1)
err_intensities_0kgy_d1 = stdev_intensities_0kgy_d1/math.sqrt(len(intensities_0kgy_d1))
print('d1')
print(avg_intensities_0kgy_d1)
print(stdev_intensities_0kgy_d1)
print(err_intensities_0kgy_d1)

intensities_0kgy_d2 = intensities_0kgy['d2a1'].tolist()
intensities_0kgy_d2.extend(intensities_0kgy['d2a2'].tolist())
intensities_0kgy_d2.extend(intensities_0kgy['d2b1'].tolist())
intensities_0kgy_d2.extend(intensities_0kgy['d2b2'].tolist())
intensities_0kgy_d2.extend(intensities_0kgy['d2c1'].tolist())
intensities_0kgy_d2.extend(intensities_0kgy['d2c2'].tolist())
avg_intensities_0kgy_d2 = statistics.mean(intensities_0kgy_d2)
stdev_intensities_0kgy_d2 = statistics.stdev(intensities_0kgy_d2)
err_intensities_0kgy_d2 = stdev_intensities_0kgy_d2/math.sqrt(len(intensities_0kgy_d2))
print('d2')
print(avg_intensities_0kgy_d2)
print(stdev_intensities_0kgy_d2)
print(err_intensities_0kgy_d2)

intensities_0kgy_g = intensities_0kgy['ga1'].tolist()
intensities_0kgy_g.extend(intensities_0kgy['ga2'].tolist())
intensities_0kgy_g.extend(intensities_0kgy['gb1'].tolist())
intensities_0kgy_g.extend(intensities_0kgy['gb2'].tolist())
intensities_0kgy_g.extend(intensities_0kgy['gc1'].tolist())
intensities_0kgy_g.extend(intensities_0kgy['gc2'].tolist())
avg_intensities_0kgy_g = statistics.mean(intensities_0kgy_g)
stdev_intensities_0kgy_g = statistics.stdev(intensities_0kgy_g)
err_intensities_0kgy_g = stdev_intensities_0kgy_g/math.sqrt(len(intensities_0kgy_g))
print('g')
print(avg_intensities_0kgy_g)
print(stdev_intensities_0kgy_g)
print(err_intensities_0kgy_g)

intensities_0kgy_h = intensities_0kgy['ha1'].tolist()
intensities_0kgy_h.extend(intensities_0kgy['ha2'].tolist())
intensities_0kgy_h.extend(intensities_0kgy['hb1'].tolist())
intensities_0kgy_h.extend(intensities_0kgy['hb2'].tolist())
intensities_0kgy_h.extend(intensities_0kgy['hc1'].tolist())
intensities_0kgy_h.extend(intensities_0kgy['hc2'].tolist())
avg_intensities_0kgy_h = statistics.mean(intensities_0kgy_h)
stdev_intensities_0kgy_h = statistics.stdev(intensities_0kgy_h)
err_intensities_0kgy_h = stdev_intensities_0kgy_h/math.sqrt(len(intensities_0kgy_h))
print('h')
print(avg_intensities_0kgy_h)
print(stdev_intensities_0kgy_h)
print(err_intensities_0kgy_h)
# Out:
# d1
# 349.7307549019608
# 83.12075213944145
# 8.23018085012411
# d2
# 88.45842156862746
# 27.784440721145657
# 2.751069571302343
# g
# 97.18846078431372
# 21.670207650077025
# 2.1456702860518098
# h
# 494.9087156862745
# 122.74973699621981
# 12.154035048784003

# %%
HU_0k = pd.DataFrame(data={"area": residues_0kgy_h,"protein": ['HU'] * len(residues_0kgy_h),
                                                   "radiation": ['0kGy'] * len(residues_0kgy_h)})
GyrA_0k = pd.DataFrame(data={"area": residues_0kgy_g,"protein": ['GyrA'] * len(residues_0kgy_g),
                                                   "radiation": ['0kGy'] * len(residues_0kgy_g)})
DPS1_0k = pd.DataFrame(data={"area": residues_0kgy_d1,"protein": ['DPS1'] * len(residues_0kgy_d1),
                                                   "radiation": ['0kGy'] * len(residues_0kgy_d1)})
DPS2_0k = pd.DataFrame(data={"area": residues_0kgy_d2,"protein": ['DPS2'] * len(residues_0kgy_d2),
                                                   "radiation": ['0kGy'] * len(residues_0kgy_d2)})

HU_10k = pd.DataFrame(data={"area": residues_10kgy_h,"protein": ['HU'] * len(residues_10kgy_h),
                                                   "radiation": ['10kGy'] * len(residues_10kgy_h)})
GyrA_10k = pd.DataFrame(data={"area": residues_10kgy_g,"protein": ['GyrA'] * len(residues_10kgy_g),
                                                   "radiation": ['10kGy'] * len(residues_10kgy_g)})
DPS1_10k = pd.DataFrame(data={"area": residues_10kgy_d1,"protein": ['DPS1'] * len(residues_10kgy_d1),
                                                   "radiation": ['10kGy'] * len(residues_10kgy_d1)})
DPS2_10k = pd.DataFrame(data={"area": residues_10kgy_d2,"protein": ['DPS2'] * len(residues_10kgy_d2),
                                                   "radiation": ['10kGy'] * len(residues_10kgy_d2)})

residues = HU_0k.append(GyrA_0k)
residues = residues.append(DPS1_0k)
residues = residues.append(DPS2_0k)
residues = residues.append(HU_10k)
residues = residues.append(GyrA_10k)
residues = residues.append(DPS1_10k)
residues = residues.append(DPS2_10k)

plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
custom_palette = {"0kGy": "tab:blue", "10kGy": "orange"}
ax=sns.violinplot(x="protein",
            y="area",
            hue="radiation",
            data=residues,
            palette=custom_palette,
            width=0.8,showfliers=False)
# Add jitter with the swarmplot function
#ax = sns.swarmplot(data=[NFA_FC_dsr2_0k_718,NFA_FC_dsr2_0k_314,
 #                      NFA_FC_dsr6_0k_718,NFA_FC_dsr6_0k_429,
  #                     NFA_FC_dsr9_0k_718,NFA_FC_dsr9_0k_506,
   #                    NFA_FC_dsr20_0k_718,NFA_FC_dsr20_0k_506,
    #                   NFA_FC_dsr27_0k_718,NFA_FC_dsr27_0k_314], color="black")

plt.title("Protein Residual\n")
plt.xlabel("protein")
ax.set_xticklabels(["HU", "GyrA", "DPS1", "DPS2"],size=15)
plt.ylabel("area (square microns)")
plt.ylim([-1,10])
ax.tick_params(axis='y', labelsize=15)

# %%
HU_0k = pd.DataFrame(data={"area": footprints_0kgy_h,"protein": ['HU'] * len(footprints_0kgy_h),
                                                   "radiation": ['0kGy'] * len(footprints_0kgy_h)})
GyrA_0k = pd.DataFrame(data={"area": footprints_0kgy_g,"protein": ['GyrA'] * len(footprints_0kgy_g),
                                                   "radiation": ['0kGy'] * len(footprints_0kgy_g)})
DPS1_0k = pd.DataFrame(data={"area": footprints_0kgy_d1,"protein": ['DPS1'] * len(footprints_0kgy_d1),
                                                   "radiation": ['0kGy'] * len(footprints_0kgy_d1)})
DPS2_0k = pd.DataFrame(data={"area": footprints_0kgy_d2,"protein": ['DPS2'] * len(footprints_0kgy_d2),
                                                   "radiation": ['0kGy'] * len(footprints_0kgy_d2)})

HU_10k = pd.DataFrame(data={"area": footprints_10kgy_h,"protein": ['HU'] * len(footprints_10kgy_h),
                                                   "radiation": ['10kGy'] * len(footprints_10kgy_h)})
GyrA_10k = pd.DataFrame(data={"area": footprints_10kgy_g,"protein": ['GyrA'] * len(footprints_10kgy_g),
                                                   "radiation": ['10kGy'] * len(footprints_10kgy_g)})
DPS1_10k = pd.DataFrame(data={"area": footprints_10kgy_d1,"protein": ['DPS1'] * len(footprints_10kgy_d1),
                                                   "radiation": ['10kGy'] * len(footprints_10kgy_d1)})
DPS2_10k = pd.DataFrame(data={"area": footprints_10kgy_d2,"protein": ['DPS2'] * len(footprints_10kgy_d2),
                                                   "radiation": ['10kGy'] * len(footprints_10kgy_d2)})

footprints = HU_0k.append(GyrA_0k)
footprints = footprints.append(DPS1_0k)
footprints = footprints.append(DPS2_0k)
footprints = footprints.append(HU_10k)
footprints = footprints.append(GyrA_10k)
footprints = footprints.append(DPS1_10k)
footprints = footprints.append(DPS2_10k)

plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
custom_palette = {"0kGy": "tab:blue", "10kGy": "orange"}
ax=sns.violinplot(x="protein",
            y="area",
            hue="radiation",
            data=footprints,
            palette=custom_palette,
            width=0.8,showfliers=False)
# Add jitter with the swarmplot function
#ax = sns.swarmplot(data=[NFA_FC_dsr2_0k_718,NFA_FC_dsr2_0k_314,
 #                      NFA_FC_dsr6_0k_718,NFA_FC_dsr6_0k_429,
  #                     NFA_FC_dsr9_0k_718,NFA_FC_dsr9_0k_506,
   #                    NFA_FC_dsr20_0k_718,NFA_FC_dsr20_0k_506,
    #                   NFA_FC_dsr27_0k_718,NFA_FC_dsr27_0k_314], color="black")

plt.title("Protein Footprint\n")
plt.xlabel("protein")
ax.set_xticklabels(["HU", "GyrA", "DPS1", "DPS2"],size=15)
plt.ylabel("area (square microns)")
plt.ylim([-1,10])
ax.tick_params(axis='y', labelsize=15)

# %%
HU_0k = pd.DataFrame(data={"area": intensities_0kgy_h,"protein": ['HU'] * len(intensities_0kgy_h),
                                                   "radiation": ['0kGy'] * len(intensities_0kgy_h)})
GyrA_0k = pd.DataFrame(data={"area": intensities_0kgy_g,"protein": ['GyrA'] * len(intensities_0kgy_g),
                                                   "radiation": ['0kGy'] * len(intensities_0kgy_g)})
DPS1_0k = pd.DataFrame(data={"area": intensities_0kgy_d1,"protein": ['DPS1'] * len(intensities_0kgy_d1),
                                                   "radiation": ['0kGy'] * len(intensities_0kgy_d1)})
DPS2_0k = pd.DataFrame(data={"area": intensities_0kgy_d2,"protein": ['DPS2'] * len(intensities_0kgy_d2),
                                                   "radiation": ['0kGy'] * len(intensities_0kgy_d2)})

HU_10k = pd.DataFrame(data={"area": intensities_10kgy_h,"protein": ['HU'] * len(intensities_10kgy_h),
                                                   "radiation": ['10kGy'] * len(intensities_10kgy_h)})
GyrA_10k = pd.DataFrame(data={"area": intensities_10kgy_g,"protein": ['GyrA'] * len(intensities_10kgy_g),
                                                   "radiation": ['10kGy'] * len(intensities_10kgy_g)})
DPS1_10k = pd.DataFrame(data={"area": intensities_10kgy_d1,"protein": ['DPS1'] * len(intensities_10kgy_d1),
                                                   "radiation": ['10kGy'] * len(intensities_10kgy_d1)})
DPS2_10k = pd.DataFrame(data={"area": intensities_10kgy_d2,"protein": ['DPS2'] * len(intensities_10kgy_d2),
                                                   "radiation": ['10kGy'] * len(intensities_10kgy_d2)})

intensities = HU_0k.append(GyrA_0k)
intensities = intensities.append(DPS1_0k)
intensities = intensities.append(DPS2_0k)
intensities = intensities.append(HU_10k)
intensities = intensities.append(GyrA_10k)
intensities = intensities.append(DPS1_10k)
intensities = intensities.append(DPS2_10k)

plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
custom_palette = {"0kGy": "tab:blue", "10kGy": "orange"}
ax=sns.violinplot(x="protein",
            y="area",
            hue="radiation",
            data=intensities,
            palette=custom_palette,
            width=0.8,showfliers=False)
# Add jitter with the swarmplot function
#ax = sns.swarmplot(data=[NFA_FC_dsr2_0k_718,NFA_FC_dsr2_0k_314,
 #                      NFA_FC_dsr6_0k_718,NFA_FC_dsr6_0k_429,
  #                     NFA_FC_dsr9_0k_718,NFA_FC_dsr9_0k_506,
   #                    NFA_FC_dsr20_0k_718,NFA_FC_dsr20_0k_506,
    #                   NFA_FC_dsr27_0k_718,NFA_FC_dsr27_0k_314], color="black")

plt.title("Protein Intensity\n")
plt.xlabel("protein")
ax.set_xticklabels(["HU", "GyrA", "DPS1", "DPS2"],size=15)
plt.ylabel("grey value")
plt.ylim([0,1200])
ax.tick_params(axis='y', labelsize=15)

# %%
HU_0k = pd.DataFrame(data={"area": intensities_0kgy_h,"protein": ['HU'] * len(intensities_0kgy_h),
                                                   "radiation": ['0kGy'] * len(intensities_0kgy_h)})
GyrA_0k = pd.DataFrame(data={"area": intensities_0kgy_g,"protein": ['GyrA'] * len(intensities_0kgy_g),
                                                   "radiation": ['0kGy'] * len(intensities_0kgy_g)})
DPS1_0k = pd.DataFrame(data={"area": intensities_0kgy_d1,"protein": ['DPS1'] * len(intensities_0kgy_d1),
                                                   "radiation": ['0kGy'] * len(intensities_0kgy_d1)})
DPS2_0k = pd.DataFrame(data={"area": intensities_0kgy_d2,"protein": ['DPS2'] * len(intensities_0kgy_d2),
                                                   "radiation": ['0kGy'] * len(intensities_0kgy_d2)})

HU_10k = pd.DataFrame(data={"area": intensities_10kgy_h,"protein": ['HU'] * len(intensities_10kgy_h),
                                                   "radiation": ['10kGy'] * len(intensities_10kgy_h)})
GyrA_10k = pd.DataFrame(data={"area": intensities_10kgy_g,"protein": ['GyrA'] * len(intensities_10kgy_g),
                                                   "radiation": ['10kGy'] * len(intensities_10kgy_g)})
DPS1_10k = pd.DataFrame(data={"area": intensities_10kgy_d1,"protein": ['DPS1'] * len(intensities_10kgy_d1),
                                                   "radiation": ['10kGy'] * len(intensities_10kgy_d1)})
DPS2_10k = pd.DataFrame(data={"area": intensities_10kgy_d2,"protein": ['DPS2'] * len(intensities_10kgy_d2),
                                                   "radiation": ['10kGy'] * len(intensities_10kgy_d2)})

intensities = HU_0k.append(GyrA_0k)
intensities = intensities.append(DPS1_0k)
intensities = intensities.append(DPS2_0k)
#intensities = intensities.append(HU_10k)
#intensities = intensities.append(GyrA_10k)
#intensities = intensities.append(DPS1_10k)
#intensities = intensities.append(DPS2_10k)

plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
custom_palette = {"HU": "tab:blue", "DPS1": "red","DPS2": "orange", "GyrA": "yellow"}
ax=sns.kdeplot(x="area",
            hue="protein",
            data=intensities,
            palette=custom_palette)

plt.title("Protein Intensity\n")
plt.xlabel("grey value")
#ax.set_xticklabels(["HU", "GyrA", "DPS1", "DPS2"],size=15)
#plt.ylabel("grey value")
plt.ylim([0,.01])
ax.tick_params(axis='y', labelsize=15)

# %%
HU_0k = pd.DataFrame(data={"area": footprints_0kgy_h,"protein": ['HU'] * len(footprints_0kgy_h),
                                                   "radiation": ['0kGy'] * len(footprints_0kgy_h)})
GyrA_0k = pd.DataFrame(data={"area": footprints_0kgy_g,"protein": ['GyrA'] * len(footprints_0kgy_g),
                                                   "radiation": ['0kGy'] * len(footprints_0kgy_g)})
DPS1_0k = pd.DataFrame(data={"area": footprints_0kgy_d1,"protein": ['DPS1'] * len(footprints_0kgy_d1),
                                                   "radiation": ['0kGy'] * len(footprints_0kgy_d1)})
DPS2_0k = pd.DataFrame(data={"area": footprints_0kgy_d2,"protein": ['DPS2'] * len(footprints_0kgy_d2),
                                                   "radiation": ['0kGy'] * len(footprints_0kgy_d2)})

HU_10k = pd.DataFrame(data={"area": footprints_10kgy_h,"protein": ['HU'] * len(footprints_10kgy_h),
                                                   "radiation": ['10kGy'] * len(footprints_10kgy_h)})
GyrA_10k = pd.DataFrame(data={"area": footprints_10kgy_g,"protein": ['GyrA'] * len(footprints_10kgy_g),
                                                   "radiation": ['10kGy'] * len(footprints_10kgy_g)})
DPS1_10k = pd.DataFrame(data={"area": footprints_10kgy_d1,"protein": ['DPS1'] * len(footprints_10kgy_d1),
                                                   "radiation": ['10kGy'] * len(footprints_10kgy_d1)})
DPS2_10k = pd.DataFrame(data={"area": footprints_10kgy_d2,"protein": ['DPS2'] * len(footprints_10kgy_d2),
                                                   "radiation": ['10kGy'] * len(footprints_10kgy_d2)})

footprints = HU_0k.append(GyrA_0k)
footprints = footprints.append(DPS1_0k)
footprints = footprints.append(DPS2_0k)
#footprints = footprints.append(HU_10k)
#footprints = footprints.append(GyrA_10k)
#footprints = footprints.append(DPS1_10k)
#footprints = footprints.append(DPS2_10k)

plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
custom_palette = {"HU": "tab:blue", "DPS1": "red","DPS2": "orange", "GyrA": "yellow"}
ax=sns.kdeplot(x="area",
            hue="protein",
            data=footprints,
            palette=custom_palette)

plt.title("Protein Footprint\n")
plt.xlabel("area")
#ax.set_xticklabels(["HU", "GyrA", "DPS1", "DPS2"],size=15)
#plt.ylabel("grey value")
plt.ylim([0,.1])
ax.tick_params(axis='y', labelsize=15)

# %%
HU_0k = pd.DataFrame(data={"area": residues_0kgy_h,"protein": ['HU'] * len(residues_0kgy_h),
                                                   "radiation": ['0kGy'] * len(residues_0kgy_h)})
GyrA_0k = pd.DataFrame(data={"area": residues_0kgy_g,"protein": ['GyrA'] * len(residues_0kgy_g),
                                                   "radiation": ['0kGy'] * len(residues_0kgy_g)})
DPS1_0k = pd.DataFrame(data={"area": residues_0kgy_d1,"protein": ['DPS1'] * len(residues_0kgy_d1),
                                                   "radiation": ['0kGy'] * len(residues_0kgy_d1)})
DPS2_0k = pd.DataFrame(data={"area": residues_0kgy_d2,"protein": ['DPS2'] * len(residues_0kgy_d2),
                                                   "radiation": ['0kGy'] * len(residues_0kgy_d2)})

HU_10k = pd.DataFrame(data={"area": residues_10kgy_h,"protein": ['HU'] * len(residues_10kgy_h),
                                                   "radiation": ['10kGy'] * len(residues_10kgy_h)})
GyrA_10k = pd.DataFrame(data={"area": residues_10kgy_g,"protein": ['GyrA'] * len(residues_10kgy_g),
                                                   "radiation": ['10kGy'] * len(residues_10kgy_g)})
DPS1_10k = pd.DataFrame(data={"area": residues_10kgy_d1,"protein": ['DPS1'] * len(residues_10kgy_d1),
                                                   "radiation": ['10kGy'] * len(residues_10kgy_d1)})
DPS2_10k = pd.DataFrame(data={"area": residues_10kgy_d2,"protein": ['DPS2'] * len(residues_10kgy_d2),
                                                   "radiation": ['10kGy'] * len(residues_10kgy_d2)})

residues = HU_0k.append(GyrA_0k)
residues = residues.append(DPS1_0k)
residues = residues.append(DPS2_0k)
#residues = residues.append(HU_10k)
#residues = residues.append(GyrA_10k)
#residues = residues.append(DPS1_10k)
#residues = residues.append(DPS2_10k)

plt.rc('axes', titlesize=20)
plt.rc('axes', labelsize=20)
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
custom_palette = {"HU": "tab:blue", "DPS1": "red","DPS2": "orange", "GyrA": "yellow"}
ax=sns.kdeplot(x="area",
            hue="protein",
            data=residues,
            palette=custom_palette)

plt.title("Protein Residue\n")
plt.xlabel("area")
#ax.set_xticklabels(["HU", "GyrA", "DPS1", "DPS2"],size=15)
#plt.ylabel("grey value")
plt.ylim([0,.2])
ax.tick_params(axis='y', labelsize=15)
